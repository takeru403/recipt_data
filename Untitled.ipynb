# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## データ全体のユーザー分布

# %%
df = pd.read_csv("hoge.csv",names=("purchasedat", "gender", "age", "quantity", "receiptid","publicuserid", "chainstorename", "jicfscategoryss", "matchedname"))

# %%
df.head()
# Out:
#                                          purchasedat  gender  age  quantity  \
# 0  2022-09-16 13:48:00 "female" "24" "1" "2885473...     NaN  NaN       NaN
# 1  2022-08-10 16:50:00 "female" "34" "1" "2669296...     NaN  NaN       NaN
# 2  2022-11-27 14:55:00 "female" "41" "1" "3309295...     NaN  NaN       NaN
# 3  2022-06-28 17:07:00 "male" "46" "2" "241199144...     NaN  NaN       NaN
# 4  2022-08-29 18:06:00 "female" "26" "1" "2790773...     NaN  NaN       NaN
#
#    receiptid  publicuserid  chainstorename  jicfscategoryss  matchedname
# 0        NaN           NaN             NaN              NaN          NaN
# 1        NaN           NaN             NaN              NaN          NaN
# 2        NaN           NaN             NaN              NaN          NaN
# 3        NaN           NaN             NaN              NaN          NaN
# 4        NaN           NaN             NaN              NaN          NaN

# %%
len(df)
# Out:
# 5791412

# %%
foo = pd.read_csv("ho.csv")

# %%
foo
# Out:
#    2022-09-16,13:48:00  female  24  1  288547349  \
# 0  2022-08-10,16:50:00  female  34  1  266929695
# 1  2022-11-27,14:55:00  female  41  1  330929503
# 2  2022-06-28,17:07:00    male  46  2  241199144
# 3  2022-08-29,18:06:00  female  26  1  279077322
# 4  2022-08-21,13:33:00  female  24  1  275251702
# 5  2022-11-05,12:26:00    male  50  1  317259547
# 6  2022-07-08,12:34:00  female  54  1  246011589
# 7  2022-11-02,10:11:00  female  50  1  316621222
# 8  2022-07-13,10:56:00    male  53  1  250009305
# 9  2022-11-19,18:06:00    male  56  1  325357304
#
#    f2930de3-b5e3-4f5b-84fe-eaec10766615  ダイソー  130125_チュ－インガム  \
# 0  00000003-0000-0000-0000-00DE00655541  ダイソー    299999_日用品不明
# 1  8f9346ce-b5b1-4e7f-984a-ec5d71d560fb  ダイソー   239897_その他化粧品
# 2  695c8971-b8cd-4b97-9de0-934957476604  ダイソー    299999_日用品不明
# 3  52c75cff-b214-467b-8462-b7fe230c1bb6  ダイソー  240197_その他食品包装
# 4  46de820f-6b1b-4c83-be26-54f19f123b0f  ダイソー  199799_その他食品不明
# ...
